# %%
import pandas as pd

# %%
df = pd.read_csv("insuranceFraud.csv")
df.shape
# Out:
# (1000, 39)

# %%
df = df.sample(500)
df.shape
# Out:
# (500, 39)

# %%
df.to_csv("data.csv", index=False)
df.head()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 450                  33   32         263159         3/7/2008           OH
# 501                  26   39         493161        1/30/1992           IN
# 245                 371   51         513099       10/15/2005           IN
# 906                 225   43         221186        8/13/2004           OH
# 624                 127   31         856153         7/9/2002           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 450    100/300                500                1402.78         5000000
# 501    250/500               1000                 770.76               0
# 245   500/1000               1000                1532.47               0
# 906    100/300               1000                1517.54               0
# 624   500/1000                500                1255.02               0
#
#      insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...
