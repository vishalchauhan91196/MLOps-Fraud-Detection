# %%
import pandas as pd

# %%
df = pd.read_csv("insuranceFraud.csv")
df.shape
# Out:
# (1000, 39)

# %%
df = df.sample(500)
df.shape
# Out:
# (500, 39)

# %%
df.to_csv("data.csv", index=False)
df.head()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 535                  65   23         876699       12/12/1999           OH
# 614                 131   33         432740        10/9/1990           IL
# 972                 232   44         221854        10/3/1994           OH
# 476                  67   29         662256       11/13/1995           IL
# 206                 128   32         547744         7/8/2001           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 535    250/500               1000                1099.95               0
# 614    100/300               2000                1081.17               0
# 972    250/500               2000                1181.64               0
# 476    250/500               1000                1861.43               0
# 206    100/300               2000                 768.91               0
#
#      insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
for col in df:
    print(df[col].counts())
# Out:
# months_as_customer
# 140    6
# 194    6
# 230    5
# 103    5
# 143    5
#       ..
# 192    1
# 352    1
# 338    1
# 132    1
# 157    1
# Name: count, Length: 293, dtype: int64
# age
# 30    25
# 39    25
# 34    24
# 43    21
# 33    21
# 29    20
# 37    20
# 42    20
# 40    18
# 31    18
# 35    17
# 38    17
# 32    17
# 41    17
# 27    16
# 47    16
# 44    16
# 46    16
# 45    15
# 28    12
# 36    12
# 55    11
# 26    10
# 48    10
# 49     8
# 23     7
# 57     7
# 54     7
# 53     6
# 50     5
# 25     5
# 58     5
# 60     5
# 24     5
# 56     4
# 61     4
# 21     4
# 51     4
# 59     2
# 62     2
# 52     1
# 22     1
# 19     1
# 20     1
# 64     1
# 63     1
# Name: count, dtype: int64
# policy_number
# 876699    1
# 432740    1
# 221854    1
# 662256    1
# 547744    1
#          ..
# 601042    1
# 684653    1
# 437442    1
# 277767    1
# 347984    1
# Name: count, Length: 500, dtype: int64
# policy_bind_date
# 8/5/1992     3
# 9/19/1995    2
# ...
